# %% [markdown]
# # Џупитер (Jupyter) тест број 1

# %% [markdown]
# ## У ћелију испод унеси своје презиме, име и одељење

# %% [markdown]
# ## Прва група ради непарне задатке (1,3,5,...), а друга парне (2,4,6,...).
# ## Имате десет задатака. Сваки задатак носи један бод.
#
# ## Критеријум за оцењивање:
#
# |  Бодови    | |  Оцена |
# |----------|----|-------|
# |   1-2       |-->|1|
# |   3-4       |-->|2|
# |   5-6       |-->|3|
# |   7-8       |-->|4|
# |   9 - 10    |-->|5|

# %% [markdown]
# **Задатак 1.** Направи ћелију испод ове и у њој напиши Пајтон израз који налази број који се добија када се разлици бројева 995 и 132 дода производ бројева 16 и 34.

# %% [markdown]
# **Задатак 2.** Нађи осми степен броја 12.34.

# %% [markdown]
# **Задатак 3.** Променљива `BrLjudiNaSvetu_2023` има вредност 8.017.640.774. Процењује се да 28,7% становништва света живи у градовима. Направи ћелију испод и нађи колико људи живи ван градова.

# %% [markdown]
# **Задатак 4.** Милица је желела да купи панталоне које су коштале 13.799,99 динара, али јој је мама рекла да су прескупе. Зато је Милица сачекала сезону снижења и када је следећи пут обишла продавницу видела је да је цена панталона снижена за 33%. Мама је пристала да јој купи панталоне по сниженој цени. Када су дошле до касе пријатно су биле изненађене чињеницом да су добиле попуст од 5% на већ снижену цену зато што је њена мама панталоне платила готовином. Колико су на крају коштале панталоне?

# %% [markdown]
# **Задатак 5.** Из неке библиотеке можемо увести функцију или константу која нам је потребна. Наредба
#
# `from math import pi`
#
# дословно значи: из библиотеке `math` увези појам `pi`. Тиме смо у програм увели име `pi` и слободно можемо да га користимо.
#
# Напиши Пајтон програм који одређује хипотенузу $c$ правоуглог троугла ако знамо његове катете $a$ и $b$. (Да се подсетимо, према Питагориној теореми је $c = \sqrt{a^2 + b^2}$.)
#
# За овај програм је потребна функција `sqrt` која рачуна корен неког броја и која се такође налази у библиотеци `math`.

# %% [markdown]
# **Задатак 6.**
#
# (а) Једна књига је коштала 9650 динара, а онда је књижара снизила њену цену за 15%. Колико сада кошта књига?
#
# (б) Друга књига у истој књижари након снижења од 25% кошта 2430 динара. Колико је коштала пре снижења?

# %% [markdown]
# **Задатак 7.** Процењује се да је Кина на дан 1.7.2022. имала 1.435.024.921 становника. Број становника у Кини се сваке године повећа за 0,35%. Под претпоставком да се годишњи раст броја становника у Кини неће мењати, колико становника ће Кина имати 2023. године?

# %% [markdown]
# **Задатак 8.** Процењује се да је Кина на дан 1.7.2019. имала 1.420.062.022 становника, а Индија 1.368.737.513. Број становника у Кини се сваке године повећа за 0,35%, а у Индији за 1,08%. Након колико година ће Индија престићи Кину по броју становника, под претпоставком да се годишњи раст броја становника ни у једној од ове две државе неће мењати?

# %% [markdown]
# **Задатак 9.** Напиши Пајтон програм који учитава полупречник круга, а онда рачуна и штампа његову површину. (Помоћ: `pi` се налази у библиотеци `math`.)

# %% [markdown]
# **Задатак 10.** Растојање две тачке дате у равни својим координатама $A(x_1, y_1)$ и $B(x_2, y_2)$ може се израчунати помоћу формуле
#
# $$d(A, B) = \sqrt{(x_1 - x_2)^2 + (y_1 - y_2)^2}$$
#
# Напиши Пајтон програм који учитава координате две тачке у равни и потом рачуна и штампа њихово растојање. (Помоћ: `sqrt` се налази у библиотеци `math`; ако ти ова формула делује застрашујуће не брини: то само прерушена Питагорина теорема!)

# %% [markdown]
# **Задатак 11.** *Факторијел* броја $n$ је производ свих бројева од 1 до $n$ и означава се овако:
#
# $$n! = 1 \cdot 2 \cdot 3 \cdot \dots \cdot n.$$
#
# Израчунај број 200! и утврди са колико нула се завршава. (Помоћ: библиотека `math` има функцију `factorial`.)

# %% [markdown]
# **Задатак 12.** Уколико су катете правоуглог троугла 3 и 4, хипотенуза је 5. Напиши програм и нађи још неки пар целих бројева $a$ и $b$ такав да је хипотенуза правоуглог троугла са катетама $a$ и $b$ целобројна. Уместо `3, 4` унеси неки други пар целих бројева, изврши ћелију и експериментиши! (Такве тројке целих бројева се зову *Питагорине тројке*.)

# %% [markdown]
# ## Низови

# %% [markdown]
# **Задатак 13.** Напиши Пајтон наредбу којом се налази дужина низа "godine":

# %% [markdown]
# godine = [1000,  1500, 1650, 1750, 1804, 1850, 1900, 1930, 1950, 1960, 1974, 1980, 1987, 1999, 2011, 2020, 2023, 2030, 2037, 2045, 2055, 2100]

# %% [markdown]
# **Задатак 14.** Напиши Пајтон наредбу којом се налази сума низа "ljudi":

# %%
ljudi  = [0.275, 0.45, 0.5,  0.7,  1,    1.2,  1.6,  2,    2.55, 3,    4,    4.5,  5,    6,    7,    7.8,  8,    8.5,  9,    9.5,  10,   11.2]

# %%
nizA=[2,3,8,4,-5,-7,3,2,6,8,1,4,-2,9,1,3,5,-4,0,4,5,6,9,3,9,6,7,-7,-7,0,3,4,5,1,-7,9,-8]

# %%
nizB=[2,3,8,-8,-5,-7,3,2,6,-8,1,4,-2,9,1,3,5,-4,4,-8,6,9,3,9,6,7,-7,-7,-8,4,5,1,-7,9]

# %%
rec='leleleleleleeeeellellelellelelelelellelelekakvizadaci'

# %%
nizD=[22000, 35000, 41000, 38000, 35000, 39000, 48000, 36000, 41000, 33000]

# %% [markdown]
# **Задатак 15.** Напиши функцију `max_niza` која за дати низ X рачуна и враћа највећи елемент, али без употребе стандардне функције `max`. Написану функцију искористи за налажење највећег елемента датог низа који се зове `nizA`. Низ је дат у претходним ћелијама.

# %% [markdown]
# **Задатак 16.** Напиши функцију `prebroj_min` која за дати низ X пребројава колико има елемената низа који су једнаки најмањем елементу тог низа. Применити је на низ `nizB`. Низ је дат у претходним ћелијама. Дозвољено је користити уграђене функције.

# %% [markdown]
# **Задатак 17.** Напиши функцију `prebroj_е` која у датом стрингу пребројава колико има слова "е". Применити је на стринг `rec` који је дат. Стринг `rec` је дат у претходним ћелијама.

# %% [markdown]
# **Задатак 18.** Написати Пајтон функцију `saberi_cifre` која за дати позитиван цео број утврђује збир његових цифара. На пример,
#
# `saberi_cifre(354679)`
# треба да врати
#
# `34`
#
# зато што је `3 + 5 + 4 + 6 + 7 + 9 = 34`.

# %% [markdown]
# **Задатак 19.** Написати Пајтон функцију која налази производ чланова датог низа. Применити је на низ `nizB`.

# %% [markdown]
# **Задатак 20.** Написати функцију која налази просек датог низа. Применити је на низ `nizB`.
